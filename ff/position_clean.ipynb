# %% [markdown]
# ## Positional Imports

# %%
import pandas as pd
import sys
sys.path.extend(['./extras', './weekly', './models', './utils'])
import exp
from injuries import get_injuries_for_all_teams
from salary import get_salaries

# %%
final_dfs = []

# %% [markdown]
# ### Read Previous Data

# %%
f_before_2024 = pd.read_pickle('pickles/f_before_2024.pickle')
f_before_2024.rename(columns={'Team': 'team'}, inplace=True)
f_2024 = pd.read_pickle('pickles/f_2024.pickle')
f_2024.rename(columns={'Team': 'team'}, inplace=True)
f_before_2024.drop(columns='Coach', inplace=True)
f_2024.drop(columns='Coach', inplace=True)
duplicates = f_2024[f_2024.duplicated(subset=['year', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, G-season, W-season, L-season, T-season, G-w/team, W-w/team, L-w/team, T-w/team, G-career, W-career, L-career, T-career, G plyf-playoffs, W plyf-playoffs, L plyf-playoffs, G plyf-w/team, W plyf-w/team, L plyf-w/team, G plyf-career, W plyf-career, L plyf-career, Remark, w/same_team, Gms-fds, Rush-fds, Pass-fds, Pen-fds, Pct-tde, Pct-fde, gameday, weekday, gametime, away_team, home_team, away_moneyline, home_moneyline, spread_line, away_spread_odds, home_spread_odds, total_line, under_odds, over_odds, div_game, roof, surface, temp, wind, referee, stadium, bye_week, oline_rank, dline_rank]
# Index: []
#
# [0 rows x 55 columns]

# %% [markdown]
# ### Retrieve Position Info

# %%
# d1 = get_indiv(2024, 'RB')
# d2 = get_indiv(2023, 'RB')
# d3 = get_indiv(2022, 'RB')
# d4 = get_indiv(2021, 'RB')
# d1 = cum_adjust(d1, [d4, d3, d2])
# d1.to_pickle('pickles/rb_2024.pickle')
# d2 = d2 = cum_adjust(d2, [d4, d3])
# d2.to_pickle('pickles/rb_before_2024.pickle')

# exp_obj = Exp()
# df, past_df = exp_obj.get_all(2024, 'K')
# past_df.to_pickle('pickles/k_before_2024.pickle')
# df.to_pickle('pickles/k_2024.pickle')

# inj_before_2024 = pd.concat([get_injuries_for_all_teams(year, 'K') for year in range(2022, 2024)], ignore_index=True)
# inj_before_2024.to_pickle('pickles/k_inj_before_2024.pickle')
# inj_2024 = get_injuries_for_all_teams(2024, 'K')
# inj_2024.to_pickle('pickles/k_inj_2024.pickle')

# pos_salaries = get_salaries('K')
# pos_salaries.to_pickle('pickles/k_salaries.pickle')

# %% [markdown]
# # 1. Quarterbacks

# %%
qb_before_2024 = pd.read_pickle('pickles/qb_before_2024.pickle')
qb_2024 = pd.read_pickle('pickles/qb_2024.pickle')

# %%
qb_before_2024 = pd.read_pickle('pickles/qb_before_2024.pickle')
qb_2024 = pd.read_pickle('pickles/qb_2024.pickle')
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
duplicates = qb_2024[qb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
qb_exp_before_2024 = pd.read_pickle('pickles/qb_exp_before_2024.pickle')
qb_exp_2024 = pd.read_pickle('pickles/qb_exp_2024.pickle')
duplicates = qb_exp_before_2024[qb_exp_before_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
duplicates = qb_exp_2024[qb_exp_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
qb_inj_before_2024 = pd.read_pickle('pickles/qb_inj_before_2024.pickle')
qb_inj_2024 = pd.read_pickle('pickles/qb_inj_2024.pickle')
duplicates = qb_inj_before_2024[qb_inj_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
duplicates = qb_inj_2024[qb_inj_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
qb_sal = pd.read_pickle('pickles/qb_salaries.pickle')
duplicates = qb_sal[qb_sal.duplicated(subset=['player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [player_name, team, Total Value, APY, Total Guaranteed, Avg. Guarantee/Year, % Guaranteed]
# Index: []

# %% [markdown]
# ### Using team val from og qb dfs, drop others

# %%
qb_exp_before_2024 = qb_exp_before_2024.drop(columns=['team'])
qb_exp_2024 = qb_exp_2024.drop(columns=['team'])
qb_inj_before_2024 = qb_inj_before_2024.drop(columns=['team'])
qb_inj_2024 = qb_inj_2024.drop(columns=['team'])
qb_sal = qb_sal.drop(columns=['team'])

# %% [markdown]
# ### Merge qb and exp

# %%
qb_before_2024 = qb_before_2024.merge(qb_exp_before_2024, on=['year', 'player_name'], how='left')
qb_2024 = qb_2024.merge(qb_exp_2024, on=['year', 'player_name'], how='left')

# %%
qb_before_2024[qb_before_2024.isna().any(axis=1)]
# Out:
#      week  player_name  opponent_team  team  year  points depth_team  \
# 514     6  P.J. Walker              1    17  2023    3.78          1
# 515     7  P.J. Walker             18    17  2023    5.42          2
# 516     8  P.J. Walker             22    17  2023   10.62          3
# 517    10  P.J. Walker              6    17  2023    0.00          2
# 518    12  P.J. Walker             23    17  2023    0.14          2
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# 514                99            172              1093.0  ...
# 515                99            172              1093.0  ...
# 516                99            172              1093.0  ...
# 517                99            172              1093.0  ...
# 518                99            172              1093.0  ...
#
#      cum_receiving_first_downs  cum_receiving_epa  \
# 514                          0                0.0
# 515                          0                0.0
# ...

# %%
qb_before_2024 = qb_before_2024.dropna()

# %%
qb_before_2024[qb_before_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
qb_2024[qb_2024.isna().any(axis=1)]
# Out:
#      week    player_name  opponent_team  team  year  points depth_team  \
# 380    18     Joe Milton              2    30  2024   19.24          3
# 559     7  Michael Penix             22    16  2024    0.56          2
# 560    11  Michael Penix             23    16  2024    0.96          2
# 561    16  Michael Penix             29    16  2024    6.38          2
# 562    17  Michael Penix             20    16  2024   11.22          2
# 563    18  Michael Penix             26    16  2024   24.98          1
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# 380                 0              0                 0.0  ...
# 559                 0              0                 0.0  ...
# 560                 0              0                 0.0  ...
# 561                 0              0                 0.0  ...
# 562                 0              0                 0.0  ...
# 563                 0              0                 0.0  ...
#
# ...

# %%
qb_2024.loc[qb_2024['player_name'] == 'Joe Milton', ['age', 'len_with_team']] = [24, 1]
qb_2024.loc[qb_2024['player_name'] == 'Michael Penix', ['age', 'len_with_team']] = [24, 1]
qb_2024[qb_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = qb_2024[qb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Merge qb with injuries

# %%
qb_before_2024 = qb_before_2024.merge(qb_inj_before_2024, on=['year', 'week', 'player_name'], how='left')
qb_2024 = qb_2024.merge(qb_inj_2024, on=['year', 'week', 'player_name'], how='left')

# %%
qb_before_2024[qb_before_2024.isna().any(axis=1)]
# Out:
#      week      player_name  opponent_team  team  year  points depth_team  \
# 0      14      AJ McCarron             18    14  2023   -0.04          2
# 1      18      AJ McCarron             17    14  2023    0.80          2
# 2       1    Aaron Rodgers              2    31  2023    0.00          1
# 3       4  Aidan O'Connell             21    27  2023    9.82          3
# 4       7  Aidan O'Connell             19    27  2023    5.00          3
# ..    ...              ...            ...   ...   ...     ...        ...
# 680     8      Zach Wilson             29    31  2023   12.10          1
# 681     9      Zach Wilson             21    31  2023    7.22          1
# 682    10      Zach Wilson             27    31  2023   13.92          1
# 683    11      Zach Wilson              2    31  2023    6.74          1
# 684    14      Zach Wilson             15    31  2023   19.24          3
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# ...

# %%
qb_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = qb_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)

# %%
qb_before_2024[qb_before_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
qb_2024[qb_2024.isna().any(axis=1)]
# Out:
#      week    player_name  opponent_team  team  year     points depth_team  \
# 0       1  Aaron Rodgers              1    31  2024   8.580000          1
# 1       2  Aaron Rodgers             25    31  2024  15.140000          1
# 2       3  Aaron Rodgers             30    31  2024  21.040001          1
# 3       4  Aaron Rodgers             23    31  2024  11.600000          1
# 11     13  Aaron Rodgers             22    31  2024  14.000000          1
# ..    ...            ...            ...   ...   ...        ...        ...
# 691    11     Will Levis              9    25  2024  15.600000          3
# 692    12     Will Levis             15    25  2024  16.120001          3
# 693    13     Will Levis             20    25  2024  16.180000          3
# 694    14     Will Levis             12    25  2024   7.020000          1
# 696    18     Will Levis             15    25  2024  11.800000          2
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# ...

# %%
qb_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = qb_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)
qb_2024[qb_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = qb_2024[qb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
#     week     player_name  opponent_team  team  year     points depth_team  \
# 31     2  Baker Mayfield             19    24  2023  18.379999          1
# 32     2  Baker Mayfield             19    24  2023  18.379999          1
#
#     prev_completions  prev_attempts  prev_passing_yards  ...  \
# 31               454            753              5173.0  ...
# 32               454            753              5173.0  ...
#
#     cum_air_yards_share  cum_wopr  cum_points   age  len_with_team  Injury  \
# 31                  0.0       0.0       16.02  28.0            1.0    23.0
# 32                  0.0       0.0       16.02  28.0            1.0    48.0
#
#     Wed  Thu  Fri  Game Status
# 31  1.0  1.0  1.0          1.0
# 32  1.0  1.0  1.0          1.0
#
# [2 rows x 93 columns]
# Empty DataFrame
# ...

# %%
qb_before_2024 = qb_before_2024.drop(index=32)
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Merge qb with sal

# %%
qb_before_2024 = qb_before_2024.merge(qb_sal, on=['player_name'], how='left')
qb_2024 = qb_2024.merge(qb_sal, on=['player_name'], how='left')

# %%
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = qb_2024[qb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
print(qb_before_2024.isna().any().any())
print(qb_2024.isna().any().any())
# Out:
# True
# True

# %%
cols = ['Total Value', 'APY', 'Total Guaranteed', 'Avg. Guarantee/Year', '% Guaranteed']
for df in [qb_before_2024, qb_2024]:
    for col in cols:
        df[col].fillna(df[col].mean(), inplace=True)

# %%
print(qb_before_2024.isna().any().any())
print(qb_2024.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Merge with previous data

# %%
qb_before_2024 = qb_before_2024.merge(f_before_2024, on=['year', 'week', 'team'], how='left')
qb_2024 = qb_2024.merge(f_2024, on=['year', 'week', 'team'], how='left')

# %%
print(qb_before_2024.isna().any().any())
print(qb_2024.isna().any().any())
# Out:
# False
# False

# %%
duplicates = qb_before_2024[qb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
duplicates = qb_2024[qb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Add to final_dfs

# %%
final_dfs.append([qb_before_2024, qb_2024])

# %% [markdown]
# # 2. Running Backs

# %%
rb_before_2024 = pd.read_pickle('pickles/rb_before_2024.pickle')
rb_2024 = pd.read_pickle('pickles/rb_2024.pickle')
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
duplicates = rb_2024[rb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
rb_exp_before_2024 = pd.read_pickle('pickles/rb_exp_before_2024.pickle')
rb_exp_2024 = pd.read_pickle('pickles/rb_exp_2024.pickle')
duplicates = rb_exp_before_2024[rb_exp_before_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
duplicates = rb_exp_2024[rb_exp_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
rb_inj_before_2024 = pd.read_pickle('pickles/rb_inj_before_2024.pickle')
rb_inj_2024 = pd.read_pickle('pickles/rb_inj_2024.pickle')
duplicates = rb_inj_before_2024[rb_inj_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
#      year  week  team          player_name  Injury  Wed  Thu  Fri  Game Status
# 121  2022     7     7  Christian McCaffrey      66    3    4    4            1
# 132  2022     7     7  Christian McCaffrey      69    4    4    2            1

# %%
rb_inj_before_2024 = rb_inj_before_2024.drop(index=132)

# %%
duplicates = rb_inj_before_2024[rb_inj_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
duplicates = rb_inj_2024[rb_inj_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
rb_sal = pd.read_pickle('pickles/rb_salaries.pickle')
duplicates = rb_sal[rb_sal.duplicated(subset=['player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [player_name, team, Total Value, APY, Total Guaranteed, Avg. Guarantee/Year, % Guaranteed]
# Index: []

# %% [markdown]
# ### Using team val from og rb dfs, drop others

# %%
rb_exp_before_2024 = rb_exp_before_2024.drop(columns=['team'])
rb_exp_2024 = rb_exp_2024.drop(columns=['team'])
rb_inj_before_2024 = rb_inj_before_2024.drop(columns=['team'])
rb_inj_2024 = rb_inj_2024.drop(columns=['team'])
rb_sal = rb_sal.drop(columns=['team'])

# %% [markdown]
# ### Merge rb and exp

# %%
rb_before_2024 = rb_before_2024.merge(rb_exp_before_2024, on=['year', 'player_name'], how='left')
rb_2024 = rb_2024.merge(rb_exp_2024, on=['year', 'player_name'], how='left')

# %%
rb_before_2024[rb_before_2024.isna().any(axis=1)]
# Out:
#       week          player_name  opponent_team  team  year     points  \
# 238      1  Chris Rodriguez Jr.             13    20  2023   0.700000
# 239      6  Chris Rodriguez Jr.             16    20  2023   2.300000
# 240      7  Chris Rodriguez Jr.             29    20  2023   3.100000
# 241     11  Chris Rodriguez Jr.             29    20  2023   3.800000
# 242     12  Chris Rodriguez Jr.              0    20  2023   2.100000
# 243     13  Chris Rodriguez Jr.              5    20  2023   2.900000
# 244     15  Chris Rodriguez Jr.              7    20  2023   3.500000
# 245     16  Chris Rodriguez Jr.             31    20  2023  19.500000
# 619      4        JaMycal Hasty             16    12  2023   0.000000
# 933      1   Kenneth Walker III              7    22  2023  10.700000
# 934      2   Kenneth Walker III              4    22  2023  18.400000
# 935      3   Kenneth Walker III             26    22  2023  30.600000
# ...

# %%
rb_before_2024.loc[rb_before_2024['player_name'] == 'Kenneth Walker III', ['age', 'len_with_team']] = [23, 2]
rb_before_2024.loc[rb_before_2024['player_name'] == 'Chris Rodriguez Jr.', ['age', 'len_with_team']] = [23, 1]
rb_before_2024 = rb_before_2024.dropna()

# %%
rb_before_2024[rb_before_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
rb_2024[rb_2024.isna().any(axis=1)]
# Out:
#       week    player_name  opponent_team  team  year  points depth_team  \
# 94       1  Audric Estime             22    23  2024     1.4          3
# 95       6  Audric Estime             21    23  2024     1.3          3
# 96       7  Audric Estime             11    23  2024     0.9          3
# 97       8  Audric Estime             26    23  2024     0.4          3
# 98       9  Audric Estime              6    23  2024     3.5          3
# ...    ...            ...            ...   ...   ...     ...        ...
# 1438    16   Tyrone Tracy             16    29  2024    16.9          2
# 1439    17   Tyrone Tracy             18    29  2024     9.3          2
# 1440    18   Tyrone Tracy              3    29  2024     8.6          2
# 1441     1    Velus Jones             25    19  2024     2.9          1
# 1442    17    Velus Jones             24    26  2024     0.0          4
#
#       prev_completions  prev_attempts  prev_passing_yards  ...  \
# ...

# %%
rb_2024[rb_2024.isna().any(axis=1)]['player_name'].unique()
# Out:
# array(['Audric Estime', 'Ben VanSumeren', 'Chris Rodriguez',
#        'Christopher Brooks', 'Devon Achane', 'Jamycal Hasty',
#        'Jeffery Wilson', 'Kenneth Walker', 'Tyrone Tracy', 'Velus Jones'],
#       dtype=object)

# %%
rb_2024['age'].fillna(rb_2024['age'].median(), inplace=True)
rb_2024['len_with_team'].fillna(rb_2024['len_with_team'].median(), inplace=True)

# %%
rb_2024[rb_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
print(rb_before_2024.isna().any().any())
print(rb_2024.isna().any().any())
# Out:
# False
# False

# %%
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = rb_2024[rb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Merge rb with injuries

# %%
rb_before_2024 = rb_before_2024.merge(rb_inj_before_2024, on=['year', 'week', 'player_name'], how='left')
rb_2024 = rb_2024.merge(rb_inj_2024, on=['year', 'week', 'player_name'], how='left')

# %%
rb_before_2024[rb_before_2024.isna().any(axis=1)]
# Out:
#       week  player_name  opponent_team  team  year  points depth_team  \
# 2        3    AJ Dillon             11    10  2023     3.3          4
# 3        4    AJ Dillon              4    10  2023     1.1          2
# 4        5    AJ Dillon             27    10  2023    13.6          1
# 5        7    AJ Dillon             23    10  2023    11.5          4
# 6        8    AJ Dillon              9    10  2023    10.2          2
# ...    ...          ...            ...   ...   ...     ...        ...
# 1471    14  Zamir White              9    27  2023     0.8          2
# 1472    15  Zamir White             21    27  2023    17.5          2
# 1473    16  Zamir White              8    27  2023    14.5          2
# 1474    17  Zamir White             18    27  2023    15.6          2
# 1475    18  Zamir White             23    27  2023    13.1          1
#
#       prev_completions  prev_attempts  prev_passing_yards  ...  \
# ...

# %%
rb_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = rb_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)
rb_before_2024[rb_before_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
rb_2024[rb_2024.isna().any(axis=1)]
# Out:
#       week  player_name  opponent_team  team  year  points depth_team  \
# 1        2  Aaron Jones              1     9  2024     9.8          1
# 3        4  Aaron Jones             10     9  2024    17.9          1
# 4        5  Aaron Jones             31     9  2024     6.3          1
# 7        9  Aaron Jones             18     9  2024    12.2          1
# 8       10  Aaron Jones             12     9  2024    12.1          1
# ...    ...          ...            ...   ...   ...     ...        ...
# 1475     2  Zamir White              6    27  2024     6.8          1
# 1476     3  Zamir White             26    27  2024     3.4          1
# 1477     4  Zamir White             17    27  2024     3.0          1
# 1479     8  Zamir White              8    27  2024    -0.1          1
# 1481    11  Zamir White              5    27  2024     0.9          1
#
#       prev_completions  prev_attempts  prev_passing_yards  ...  \
# ...

# %%
rb_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = rb_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)
rb_2024[rb_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = rb_2024[rb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
#      week    player_name  opponent_team  team  year     points depth_team  \
# 596     3  Isiah Pacheco             19     8  2023  15.800000          1
# 597     3  Isiah Pacheco             19     8  2023  15.800000          1
# 598     4  Isiah Pacheco             31     8  2023  24.799999          1
# 599     4  Isiah Pacheco             31     8  2023  24.799999          1
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# 596                 0              0                 0.0  ...
# 597                 0              0                 0.0  ...
# 598                 0              0                 0.0  ...
# 599                 0              0                 0.0  ...
#
#      cum_air_yards_share  cum_wopr  cum_points   age  len_with_team  Injury  \
# 596            -0.054562  0.198969        17.4  24.0            2.0     4.0
# 597            -0.054562  0.198969        17.4  24.0            2.0    69.0
# ...

# %%
rb_before_2024.drop(index=[597, 599], inplace=True)

# %%
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = rb_2024[rb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Merge rb with sal

# %%
rb_before_2024 = rb_before_2024.merge(rb_sal, on=['player_name'], how='left')
rb_2024 = rb_2024.merge(rb_sal, on=['player_name'], how='left')

# %%
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = rb_2024[rb_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
print(rb_before_2024.isna().any().any())
print(rb_2024.isna().any().any())
# Out:
# True
# True

# %%
cols = ['Total Value', 'APY', 'Total Guaranteed', 'Avg. Guarantee/Year', '% Guaranteed']
for df in [rb_before_2024, rb_2024]:
    for col in cols:
        df[col].fillna(df[col].mean(), inplace=True)

# %%
print(rb_before_2024.isna().any().any())
print(rb_2024.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Merge with previous data

# %%
rb_before_2024 = rb_before_2024.merge(f_before_2024, on=['year', 'week', 'team'], how='left')
rb_2024 = rb_2024.merge(f_2024, on=['year', 'week', 'team'], how='left')

# %%
print(rb_before_2024.isna().any().any())
print(rb_2024.isna().any().any())
# Out:
# False
# False

# %%
duplicates = rb_before_2024[rb_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
duplicates = rb_2024[rb_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Append to final_dfs

# %%
final_dfs.append([rb_before_2024, rb_2024])

# %%
len(final_dfs)
# Out:
# 2

# %%
subset = rb_2024[(rb_2024['player_name'].isin(['Christian McCaffrey', 'Isaac Guerendo'])) & (rb_2024['week'] == 1)]

for index, row in subset.iterrows():
    print(" | ".join([f"{col}: {val}" for col, val in zip(subset.columns, row.values)]))
    print("-" * 50)
# Out:
# week: 1 | player_name: Christian McCaffrey | opponent_team: 31 | team: 1 | year: 2024 | points: 0.0 | depth_team: 1 | prev_completions: 1 | prev_attempts: 2 | prev_passing_yards: 34.0 | prev_passing_tds: 1 | prev_interceptions: 0.0 | prev_sacks: 0.0 | prev_sack_yards: 0.0 | prev_sack_fumbles: 0 | prev_sack_fumbles_lost: 0 | prev_passing_air_yards: 70.0 | prev_passing_yards_after_catch: 3.0 | prev_passing_first_downs: 1.0 | prev_passing_epa: 3.2338061332702637 | prev_passing_2pt_conversions: 0 | prev_pacr: 1.0967742204666138 | prev_dakota: 0.0 | prev_carries: 714 | prev_rushing_yards: 3546.0 | prev_rushing_tds: 29 | prev_rushing_fumbles: 5.0 | prev_rushing_fumbles_lost: 3.0 | prev_rushing_first_downs: 191.0 | prev_rushing_epa: 22.668062210083008 | prev_rushing_2pt_conversions: 0 | prev_receptions: 220 | prev_targets: 271 | prev_receiving_yards: 1861.0 | prev_receiving_tds: 15 | prev_receiving_fumbles: 1.0 | prev_receiving_fumbles_lost: 0.0 | prev_receiving_air_yards: 434.0 | prev_rece
# ...

# %% [markdown]
# # 3. Wide Receivers

# %%
wr_before_2024 = pd.read_pickle('pickles/wr_before_2024.pickle')
wr_2024 = pd.read_pickle('pickles/wr_2024.pickle')
duplicates = wr_before_2024[wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
duplicates = wr_2024[wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# ...

# %%
wr_exp_before_2024 = pd.read_pickle('pickles/wr_exp_before_2024.pickle')
wr_exp_2024 = pd.read_pickle('pickles/wr_exp_2024.pickle')
duplicates = wr_exp_before_2024[wr_exp_before_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
duplicates = wr_exp_2024[wr_exp_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, player_name, team, age, len_with_team]
# Index: []

# %%
wr_inj_before_2024 = pd.read_pickle('pickles/wr_inj_before_2024.pickle')
wr_inj_2024 = pd.read_pickle('pickles/wr_inj_2024.pickle')
duplicates = wr_inj_before_2024[wr_inj_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
duplicates = wr_inj_2024[wr_inj_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [year, week, team, player_name, Injury, Wed, Thu, Fri, Game Status]
# Index: []

# %%
wr_sal = pd.read_pickle('pickles/wr_salaries.pickle')
duplicates = wr_sal[wr_sal.duplicated(subset=['player_name', 'team'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [player_name, team, Total Value, APY, Total Guaranteed, Avg. Guarantee/Year, % Guaranteed]
# Index: []

# %% [markdown]
# ### Using team val from og wr dfs, drop others

# %%
wr_exp_before_2024 = wr_exp_before_2024.drop(columns=['team'])
wr_exp_2024 = wr_exp_2024.drop(columns=['team'])
wr_inj_before_2024 = wr_inj_before_2024.drop(columns=['team'])
wr_inj_2024 = wr_inj_2024.drop(columns=['team'])
wr_sal = wr_sal.drop(columns=['team'])

# %% [markdown]
# ### Merge wr and exp

# %%
wr_before_2024 = wr_before_2024.merge(wr_exp_before_2024, on=['year', 'player_name'], how='left')
wr_2024 = wr_2024.merge(wr_exp_2024, on=['year', 'player_name'], how='left')

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# True
# True

# %%
wr_before_2024['age'].fillna(wr_before_2024['age'].median(), inplace=True)
wr_before_2024['len_with_team'].fillna(wr_before_2024['len_with_team'].median(), inplace=True)
wr_2024['age'].fillna(wr_2024['age'].median(), inplace=True)
wr_2024['len_with_team'].fillna(wr_2024['len_with_team'].median(), inplace=True)

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# False
# False

# %%
print(wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %% [markdown]
# ### Merge wr with injuries

# %%
wr_before_2024 = wr_before_2024.merge(wr_inj_before_2024, on=['year', 'week', 'player_name'], how='left')
wr_2024 = wr_2024.merge(wr_inj_2024, on=['year', 'week', 'player_name'], how='left')

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# True
# True

# %%
wr_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = wr_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)
wr_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = wr_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# False
# False

# %%
duplicates = wr_before_2024[wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = wr_2024[wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
#       week       player_name  opponent_team  team  year  points depth_team  \
# 96       1      Amari Cooper             14    17  2023     6.7          1
# 97       1      Amari Cooper             14    17  2023     6.7          1
# 1124     1     Jaylen Waddle             21     5  2023    11.8          3
# 1125     1     Jaylen Waddle             21     5  2023    11.8          3
# 1331     1    Kadarius Toney              4     8  2023     1.0          2
# 1332     1    Kadarius Toney              4     8  2023     1.0          2
# 1333     2    Kadarius Toney             12     8  2023     8.8          2
# 1334     2    Kadarius Toney             12     8  2023     8.8          2
# 1335     3    Kadarius Toney             19     8  2023     0.9          1
# 1336     3    Kadarius Toney             19     8  2023     0.9          1
# 1522     1  Marquise Goodwin             14    17  2023     0.0          2
# ...

# %%
wr_before_2024.drop(index=[97, 1125, 1332, 1334, 1336, 1523, 1893, 1908], inplace=True)
wr_2024.drop(index=[1, 377, 1159, 1571, 1635, 1830], inplace=True)

# %%
print(wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %% [markdown]
# ### Merge wr with sal

# %%
wr_before_2024 = wr_before_2024.merge(wr_sal, on=['player_name'], how='left')
wr_2024 = wr_2024.merge(wr_sal, on=['player_name'], how='left')

# %%
print(wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# True
# True

# %%
cols = ['Total Value', 'APY', 'Total Guaranteed', 'Avg. Guarantee/Year', '% Guaranteed']
for df in [wr_before_2024, wr_2024]:
    for col in cols:
        df[col].fillna(df[col].mean(), inplace=True)

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Merge with previous data

# %%
wr_before_2024 = wr_before_2024.merge(f_before_2024, on=['year', 'week', 'team'], how='left')
wr_2024 = wr_2024.merge(f_2024, on=['year', 'week', 'team'], how='left')

# %%
print(wr_before_2024.isna().any().any())
print(wr_2024.isna().any().any())
# Out:
# False
# False

# %%
print(wr_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(wr_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %% [markdown]
# ### Append wr to final_dfs

# %%
final_dfs.append([wr_before_2024, wr_2024])

# %% [markdown]
# # 4. Tight Ends

# %%
te_before_2024 = pd.read_pickle('pickles/te_before_2024.pickle')
te_2024 = pd.read_pickle('pickles/te_2024.pickle')
print(te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# False
# False

# %%
te_exp_before_2024 = pd.read_pickle('pickles/te_exp_before_2024.pickle')
te_exp_2024 = pd.read_pickle('pickles/te_exp_2024.pickle')
print(te_exp_before_2024.duplicated(subset=['year', 'player_name', 'team'], keep=False).any())
print(te_exp_2024.duplicated(subset=['player_name', 'team'], keep=False).any())
print(te_exp_before_2024.isna().any().any())
print(te_exp_2024.isna().any().any())
# Out:
# False
# False
# False
# False

# %%
te_inj_before_2024 = pd.read_pickle('pickles/te_inj_before_2024.pickle')
te_inj_2024 = pd.read_pickle('pickles/te_inj_2024.pickle')
print(te_inj_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_inj_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_inj_before_2024.isna().any().any())
print(te_inj_2024.isna().any().any())
# Out:
# False
# False
# False
# False

# %%
te_sal = pd.read_pickle('pickles/te_salaries.pickle')
print(te_sal.duplicated(subset=['player_name', 'team'], keep=False).any())
print(te_sal.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Using team val from og te dfs, drop others

# %%
te_exp_before_2024 = te_exp_before_2024.drop(columns=['team'])
te_exp_2024 = te_exp_2024.drop(columns=['team'])
te_inj_before_2024 = te_inj_before_2024.drop(columns=['team'])
te_inj_2024 = te_inj_2024.drop(columns=['team'])
te_sal = te_sal.drop(columns=['team'])

# %% [markdown]
# ### Merge te and exp

# %%
te_before_2024 = te_before_2024.merge(te_exp_before_2024, on=['year', 'player_name'], how='left')
te_2024 = te_2024.merge(te_exp_2024, on=['year', 'player_name'], how='left')

# %%
print(te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# True
# True

# %%
te_before_2024['age'].fillna(te_before_2024['age'].median(), inplace=True)
te_before_2024['len_with_team'].fillna(te_before_2024['len_with_team'].median(), inplace=True)
te_2024['age'].fillna(te_2024['age'].median(), inplace=True)
te_2024['len_with_team'].fillna(te_2024['len_with_team'].median(), inplace=True)

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Merge te with injuries

# %%
te_before_2024 = te_before_2024.merge(te_inj_before_2024, on=['year', 'week', 'player_name'], how='left')
te_2024 = te_2024.merge(te_inj_2024, on=['year', 'week', 'player_name'], how='left')

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# True
# True

# %%
te_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = te_before_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)
te_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']] = te_2024[['Injury', 'Wed', 'Thu', 'Fri', 'Game Status']].fillna(0)

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# False
# False

# %%
duplicates = te_before_2024[te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False)]
print(duplicates)
duplicates = te_2024[te_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False)]
duplicates
# Out:
#      week    player_name  opponent_team  team  year  points depth_team  \
# 399     2  George Kittle              7     1  2023     6.0          1
# 400     2  George Kittle              7     1  2023     6.0          1
# 745     2   Mark Andrews             14     6  2023    15.5          3
# 746     2   Mark Andrews             14     6  2023    15.5          3
#
#      prev_completions  prev_attempts  prev_passing_yards  ...  \
# 399                 0              0                 0.0  ...
# 400                 0              0                 0.0  ...
# 745                 0              0                 0.0  ...
# 746                 0              0                 0.0  ...
#
#      cum_air_yards_share  cum_wopr  cum_points   age  len_with_team  Injury  \
# 399             0.134783  0.415776         4.9  29.0            7.0    16.0
# 400             0.134783  0.415776         4.9  29.0            7.0    13.0
# ...

# %%
te_before_2024.drop(index=[400, 746], inplace=True)
te_2024.drop(index=[262, 1119, 1121], inplace=True)

# %%
print(te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %% [markdown]
# ### Merge te with sal

# %%
te_before_2024 = te_before_2024.merge(te_sal, on=['player_name'], how='left')
te_2024 = te_2024.merge(te_sal, on=['player_name'], how='left')

# %%
print(te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# True
# True

# %%
cols = ['Total Value', 'APY', 'Total Guaranteed', 'Avg. Guarantee/Year', '% Guaranteed']
for df in [te_before_2024, te_2024]:
    for col in cols:
        df[col].fillna(df[col].mean(), inplace=True)

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# False
# False

# %% [markdown]
# ### Merge with previous data

# %%
te_before_2024 = te_before_2024.merge(f_before_2024, on=['year', 'week', 'team'], how='left')
te_2024 = te_2024.merge(f_2024, on=['year', 'week', 'team'], how='left')

# %%
print(te_before_2024.isna().any().any())
print(te_2024.isna().any().any())
# Out:
# False
# False

# %%
print(te_before_2024.duplicated(subset=['year', 'player_name', 'week', 'team'], keep=False).any())
print(te_2024.duplicated(subset=['player_name', 'week', 'team'], keep=False).any())
# Out:
# False
# False

# %% [markdown]
# ### Append te to final_dfs

# %%
final_dfs.append([te_before_2024, te_2024])

# %% [markdown]
# ### Preprocess and Save final_dfs

# %%
for col, val in final_dfs[0][0].iloc[23].items():
    print(col, val, type(val))
# Out:
# week 12 <class 'numpy.int32'>
# player_name Bailey Zappe <class 'str'>
# opponent_team 29 <class 'numpy.int64'>
# team 30 <class 'numpy.int64'>
# year 2023 <class 'numpy.int64'>
# points 0.16 <class 'numpy.float32'>
# depth_team 2 <class 'str'>
# prev_completions 65 <class 'numpy.int64'>
# prev_attempts 92 <class 'numpy.int64'>
# prev_passing_yards 781.0 <class 'numpy.float64'>
# prev_passing_tds 5 <class 'numpy.int64'>
# prev_interceptions 3.0 <class 'numpy.float64'>
# prev_sacks 6.0 <class 'numpy.float64'>
# prev_sack_yards 40.0 <class 'numpy.float64'>
# prev_sack_fumbles 2 <class 'numpy.int64'>
# prev_sack_fumbles_lost 2 <class 'numpy.int64'>
# prev_passing_air_yards 624.0 <class 'numpy.float64'>
# prev_passing_yards_after_catch 384.0 <class 'numpy.float64'>
# prev_passing_first_downs 37.0 <class 'numpy.float64'>
# prev_passing_epa 7.6850175857543945 <class 'numpy.float64'>
# prev_passing_2pt_conversions 0 <class 'numpy.int64'>
# ...

# %%
from preprocess import preprocess_dataframe
for i in range(len(final_dfs)):
    final_dfs[i][0] = preprocess_dataframe(final_dfs[i][0])
    final_dfs[i][1] = preprocess_dataframe(final_dfs[i][1])

# %%
for col, val in final_dfs[0][0].iloc[23].items():
    print(col, val)
# Out:
# year 0.0
# points 0.16
# prev_completions -0.9141283317167606
# prev_attempts -0.947976149744406
# prev_passing_yards -0.8992600388111104
# prev_passing_tds -0.800181492869388
# prev_interceptions -0.893492202458584
# prev_sacks -0.9871501679287334
# prev_sack_yards -0.962949869315335
# prev_sack_fumbles -0.7359517093892112
# prev_sack_fumbles_lost -0.17260037269321318
# prev_passing_air_yards -0.9795709726373862
# prev_passing_yards_after_catch -0.8634598345032628
# prev_passing_first_downs -0.8846139074539183
# prev_passing_epa -0.3096376401280647
# prev_passing_2pt_conversions -0.8224942972211472
# prev_pacr -0.9038745362517099
# prev_dakota -0.7307191896664854
# prev_carries -0.7476518727372604
# prev_rushing_yards -0.7077520171793833
# prev_rushing_tds -0.6515576209072331
# prev_rushing_fumbles -0.3818438960776862
# prev_rushing_fumbles_lost 0.04976585952752262
# prev_rushing_first_downs -0.7724601777420389
# prev_rushing_epa -0.543025611372683
# ...

# %%
import pickle
with open('pickles/dataframes.pickle', 'wb') as f:
    pickle.dump(final_dfs, f)
